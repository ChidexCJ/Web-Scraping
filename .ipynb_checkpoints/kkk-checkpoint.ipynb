# %%
import csv
import numpy as np
import pandas as pd
from time import sleep
import requests
from bs4 import BeautifulSoup
from random import randint

# %%
desc = []
prize  = []
rating = []

# %%
for page in range(1,11):
    pagee = requests.get(f'https://www.jumia.com.ng/catalog/?q=samsung+phones&page={page}#catalog-listing')
    soup = BeautifulSoup(pagee.text, 'html.parser')
    pg = soup.find_all('a', class_ = 'pg _act')

# %%
isHaveNextPage=True
page=1
while(isHaveNextPage):
    r=requests.get(f"https://cruisemaster.com.au/shop/?sort=featured&page={page}").text
    soup=BeautifulSoup(r,"lxml") 
    product=soup.find_all("li",class_="product")
    for data in product:
      print("title:",data.find("h4",class_="card-title").find("a").text)
      print("price:",data.find("span",class_="price").text)
      print("rating:",len(data.find_all("span",class_="icon--ratingFull")))

       print("page---",page,"---page")         
       if soup.find("li",class_='pagination-item--next') is None:
        isHaveNextPage=False
       page+=1
# Out:
#   Input In [11]
#     print("page---",page,"---page")
#     ^
# IndentationError: unexpected indent

# %%
next_page = True
page = 1
while(next_page):
    response = requests.get('https://www.jumia.com.ng/catalog/?q=samsung+phones&page='+str(page)+'#catalog-listing').text
    soup = BeautifulSoup(response, 'html.parser')
    items = soup.find_all('a', class_ = 'pg _act')
    sleep(randint(2,8))
    for data in item:
        description = [i.text for i in data.findAll('h3', class_ = 'name')] if [i.text for i in data.findAll('h3', class_ = 'name')] else " "
        price = [i.text for i in data.findAll('div', attrs = {'class':'prc'})] if [i.text for i in data.findAll('div', attrs = {'class':'prc'})] else " "
        #rating = [i.text for i in soup.findAll('div', attrs = {'class': 'in'})] if [i.text for i in soup.findAll('div', attrs = {'class': 'in'})] else " "
    if soup.find('a', class_ = 'pg') is None:
        next_page = False
    page+1
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\HP\webscrapping\scrapper\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/HP/webscrapping/scrapper/lib/site-packages/urllib3/connectionpool.py?line=701'>702</a> # Make the request on the httplib connection object.
# --> <a href='file:///c%3A/Users/HP/webscrapping/scrapper/lib/site-packages/urllib3/connectionpool.py?line=702'>703</a> httplib_response = self._make_request(
#     <a href='file:///c%3A/Users/HP/webscrapping/scrapper/lib/site-packages/urllib3/connectionpool.py?line=703'>704</a>     conn,
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://books.toscrape.com/catalogue/category/books/fantasy_19/index.html'

while True:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "lxml")

    footer_element = soup.select_one('li.current')
    print(footer_element.text.strip())
    # Do more with each page.

    # Find the next page to scrape in the pagination.
    next_page_element = soup.select_one('li.next > a')
    if next_page_element:
        next_page_url = next_page_element.get('href')
        url = urljoin(url, next_page_url)
    else:
        break

# %%
desc = []
pricee = []

# %%
page =1
url = "https://www.jumia.com.ng/catalog/?q=samsung+phones&page='+str(page)+'#catalog-listing"

while True:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    for i in soup:
        description = [i.text for i in soup.findAll('h3', class_ = 'name')] if [i.text for i in soup.findAll('h3', class_ = 'name')] else " "
        price = [i.text for i in soup.findAll('div', attrs = {'class':'prc'})] if [i.text for i in soup.findAll('div', attrs = {'class':'prc'})] else " "
        #rating = [i.text for i in soup.findAll('div', attrs = {'class': 'in'})] if [i.text for i in soup.findAll('div', attrs = {'class': 'in'})] else " "
        desc.append(description)
        pricee.append(price)
        next_page_element = items = soup.find_all('a', class_ = 'pg')
        if next_page_element:
            next_page_url = soup.find('href')
            url = urljoin(url, next_page_url)
        else:
            break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\HP\webscrapping\kkk.ipynb Cell 8' in <cell line: 4>()
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/webscrapping/kkk.ipynb#ch0000006?line=13'>14</a> next_page_element = items = soup.find_all('a', class_ = 'pg')
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/webscrapping/kkk.ipynb#ch0000006?line=14'>15</a> if next_page_element:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/HP/webscrapping/kkk.ipynb#ch0000006?line=15'>16</a>     next_page_url = next_page_element.get('href')
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/webscrapping/kkk.ipynb#ch0000006?line=16'>17</a>     url = urljoin(url, next_page_url)
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/webscrapping/kkk.ipynb#ch0000006?line=17'>18</a> else:
#
# ...
